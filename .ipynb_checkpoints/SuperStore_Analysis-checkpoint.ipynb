# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# !pip install chart-studio
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import  init_notebook_mode, plot, iplot
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import os
print(os.getcwd())
# Out:
# /Users/rouagrissa/Documents/Data Analyst/Superstore

# %%
filepath ="./store_dataset.csv"
df=pd.read_csv(filepath,encoding="cp1252")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe().T
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
gbsegment=df.groupby('Segment').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=gbsegment.index , y='Profit' , data=gbsegment , errorbar=None) 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=gbsegment.index , y='Sales' , data=gbsegment , errorbar=None)
# Out:
# <Axes: title={'center': 'Total Sales'}, xlabel='Segment', ylabel='Sales'>

# %% [markdown]
# ### As we can see here the consumer segment is the highest in the Total Profit and Total Sales

# %%
gbregion=df.groupby('Region').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=gbregion.index , y='Profit' , data=gbregion , errorbar=None) 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=gbregion.index , y='Sales' , data=gbregion , errorbar=None)
# Out:
# <Axes: title={'center': 'Total Sales'}, xlabel='Region', ylabel='Sales'>

# %% [markdown]
# ### Here we can observe that the West is the highest in both Total Profit and Total Sales then there is East who is pretty higher compared to South and Central.

# %%
gbcategory=df.groupby('Category').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=gbcategory.index , y='Profit' , data=gbcategory , errorbar=None) 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=gbcategory.index , y='Sales' , data=gbcategory , errorbar=None)
# Out:
# <Axes: title={'center': 'Total Sales'}, xlabel='Category', ylabel='Sales'>

# %% [markdown]
# ### The Technology category have the highest Total profit and Total sales among the 3 category which is the ideal scenario : lots of customer and resonable cost. Same thing goes for Office Supplies Category . However, the furniture category shows high sales and low profit which indicates thin margin or high costs.

# %%
gbshipmode=df.groupby('Ship Mode').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=gbshipmode.index , y='Profit' , data=gbshipmode , errorbar=None) 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=gbshipmode.index , y='Sales' , data=gbshipmode , errorbar=None)
# Out:
# <Axes: title={'center': 'Total Sales'}, xlabel='Ship Mode', ylabel='Sales'>

# %% [markdown]
# ### The standard Class shipping mode brings the highest total profit and total sales.

# %%
gbsubcategory=df.groupby('Sub-Category').sum()

# %%
gbsubcategory_sorted = gbsubcategory.sort_values('Profit', ascending=False)

plt.figure(figsize=(8,6))
sns.barplot(
    x='Profit',
    y=gbsubcategory_sorted.index,   # use the sorted index
    data=gbsubcategory_sorted,
    color='b',
    errorbar=None,
    palette='bright'
)
plt.title('Total Profit')
plt.show()
# Out:
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/3692795989.py:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ### In this visualisation we can observe that Tables, Supplies and Bookcase are giving negative profit meaning it is a loss. Also Fasteners and Machines are giving low profit.

# %%
gbdiscount=df.groupby('Discount').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=gbdiscount.index , y='Profit' , data=gbdiscount , errorbar=None) 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=gbdiscount.index , y='Sales' , data=gbdiscount , errorbar=None)
# Out:
# <Axes: title={'center': 'Total Sales'}, xlabel='Discount', ylabel='Sales'>

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
gbstate_sum=df.groupby('State').sum()

# %%
gbstate_sum['Abbrev']=gbstate_sum.index.map(us_state_abbrev)

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
trace = go.Choropleth(
    locations=gbstate_sum['Abbrev'],
    z=gbstate_sum['Profit'],
    locationmode='USA-states',
    colorscale='Portland',
    text=gbstate_sum.index,
    marker=dict(line=dict(color='rgb(255,255,255)', width=2)),
    colorbar={'title': "USD"}
)

# %%
layout= dict(title='Total Profits',
             geo=dict(scope='usa',
                      showlakes=True,
                      lakecolor='rgb(85,173,240)'))

# %%
choromap=go.Figure(data=[trace],layout=layout)

# %%
iplot(choromap)

# %% [markdown]
# ### From the above analysis we can conclude that New York and california bring the highest profit

# %% [markdown]
# ### Nevertheless we observe that Texas, Arizona, Colorado, Oregon, Florida, North Carolina, Tennessee, Illinois, Ohio, Pennysylvania and Wyoming, these 11 states are performing poorly in terms of Profit.
#
# ## Let's check in which segment and sectors they are lagging behind other states:

# %%
#pps: poor profit state
pps=df.loc[df['State'].isin(['Texas','Arizona','Colorado','Oregon','Florida','North Carolina','Tennessee','Illinois','Ohio','Pennysylvania','Wyoming'])]

# %%
pps['State'].unique()
# Out:
# array(['Florida', 'North Carolina', 'Texas', 'Illinois', 'Arizona',
#        'Tennessee', 'Oregon', 'Colorado', 'Ohio', 'Wyoming'], dtype=object)

# %%
pps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3292 entries, 3 to 9989
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         3292 non-null   int64
#  1   Order ID       3292 non-null   object
#  2   Order Date     3292 non-null   object
#  3   Ship Date      3292 non-null   object
#  4   Ship Mode      3292 non-null   object
#  5   Customer ID    3292 non-null   object
#  6   Customer Name  3292 non-null   object
#  7   Segment        3292 non-null   object
#  8   Country        3292 non-null   object
#  9   City           3292 non-null   object
#  10  State          3292 non-null   object
#  11  Postal Code    3292 non-null   int64
#  12  Region         3292 non-null   object
#  13  Product ID     3292 non-null   object
#  14  Category       3292 non-null   object
#  15  Sub-Category   3292 non-null   object
#  16  Product Name   3292 non-null   object
# ...

# %%
pps_gbsegment=pps.groupby('Segment').sum()
pps_gbcategory=pps.groupby('Category').sum()
pps_gbsubcategory=pps.groupby('Sub-Category').sum()

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=pps_gbsegment.index , y='Profit' , data=pps_gbsegment , errorbar=None, color='b',palette='bright') 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=pps_gbsegment.index , y='Sales' , data=pps_gbsegment , errorbar=None,color='b',palette='bright')
# Out:
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/2797410370.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/2797410370.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: title={'center': 'Total Sales'}, xlabel='Segment', ylabel='Sales'>

# %% [markdown]
# ### Profit and Sales In poor performing states are Inversly Proportional to each other

# %%
plt.figure(figsize=(14,5))
sns.set_style('whitegrid')

plt.subplot(1,2,1)
plt.title('Total Profit')
sns.barplot(x=pps_gbcategory.index , y='Profit' , data=pps_gbcategory , errorbar=None, color='b',palette='bright') 

plt.subplot(1,2,2)
plt.title('Total Sales')
sns.barplot(x=pps_gbcategory.index , y='Sales' , data=pps_gbcategory , errorbar=None,color='b',palette='bright')
# Out:
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/1031809207.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/1031809207.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: title={'center': 'Total Sales'}, xlabel='Category', ylabel='Sales'>

# %%
plt.figure(figsize=(20,10))
sns.set_style('whitegrid')

plt.subplot(2,1,1)
plt.title('Total Profit')
sns.barplot(y=pps_gbsubcategory.index , x='Profit' , data=pps_gbsubcategory , errorbar=None, color='b',palette='bright') 

plt.subplot(2,1,2)
plt.title('Total Sales')
sns.barplot(y=pps_gbsubcategory.index , x='Sales' , data=pps_gbsubcategory , errorbar=None,color='b',palette='bright')
# Out:
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/3935990314.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# /var/folders/sx/ch1z2wcs05l7n6_3cb6xkh680000gn/T/ipykernel_9048/3935990314.py:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# <Axes: title={'center': 'Total Sales'}, xlabel='Sales', ylabel='Sub-Category'>

# %% [markdown]
# ### In Poor Performing States , the Furniture Category and Customer Segment are the major factor causing loss and they need to be worked on immediately.

# %% [markdown]
# # Superstore Project Ends here :)
